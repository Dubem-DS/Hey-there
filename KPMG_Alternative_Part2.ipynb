# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Old_Cust = pd.read_excel(r'C:\Users\user\Downloads\Documents\Old_Cust_List.xlsx', sheet_name= 'Old_Cust_List')

# %%
Old_Cust
# Out:
#        past_3_years_bike_related_purchases        DOB  gender  \
# 0                                       93 1953-10-12  Female
# 1                                       93 1953-10-12  Female
# 2                                       93 1953-10-12  Female
# 3                                       93 1953-10-12  Female
# 4                                       93 1953-10-12  Female
# ...                                    ...        ...     ...
# 19508                                   71 1967-07-21  Female
# 19509                                   71 1967-07-21  Female
# 19510                                   71 1967-07-21  Female
# 19511                                   71 1967-07-21  Female
# 19512                                   71 1967-07-21  Female
#
#       job_industry_category     wealth_segment owns_car            state  \
# 0                    Health      Mass Customer      Yes  New South Wales
# ...

# %%
from datetime import date
now = pd.Timestamp('now')
Old_Cust['DOB'] = pd.to_datetime(Old_Cust['DOB'], format= '%y%m%d')
Old_Cust['DOB'] = Old_Cust['DOB'].where(Old_Cust['DOB'] < now, Old_Cust['DOB'] - np.timedelta64(100, 'Y'))
Old_Cust['age'] = (now - Old_Cust['DOB']).astype('<m8[Y]')
Old_Cust.head()
# Out:
#    past_3_years_bike_related_purchases        DOB  gender  \
# 0                                   93 1953-10-12  Female
# 1                                   93 1953-10-12  Female
# 2                                   93 1953-10-12  Female
# 3                                   93 1953-10-12  Female
# 4                                   93 1953-10-12  Female
#
#   job_industry_category wealth_segment owns_car            state order_status  \
# 0                Health  Mass Customer      Yes  New South Wales     Approved
# 1                Health  Mass Customer      Yes  New South Wales     Approved
# 2                Health  Mass Customer      Yes  New South Wales     Approved
# 3                Health  Mass Customer      Yes  New South Wales     Approved
# 4                Health  Mass Customer      Yes  New South Wales     Approved
#
#     age
# 0  66.0
# 1  66.0
# 2  66.0
# 3  66.0
# 4  66.0

# %%
Old_Cust = Old_Cust.drop(['DOB'], axis = 1)
Old_Cust
# Out:
#        past_3_years_bike_related_purchases  gender job_industry_category  \
# 0                                       93  Female                Health
# 1                                       93  Female                Health
# 2                                       93  Female                Health
# 3                                       93  Female                Health
# 4                                       93  Female                Health
# ...                                    ...     ...                   ...
# 19508                                   71  Female         Entertainment
# 19509                                   71  Female         Entertainment
# 19510                                   71  Female         Entertainment
# 19511                                   71  Female         Entertainment
# 19512                                   71  Female         Entertainment
#
#           wealth_segment owns_car            state order_status   age
# ...

# %% [markdown]
# # Rearrange a bit

# %%
Old_Cust.columns.values
# Out:
# array(['past_3_years_bike_related_purchases', 'gender',
#        'job_industry_category', 'wealth_segment', 'owns_car', 'state',
#        'order_status', 'age'], dtype=object)

# %%
cols = ['past_3_years_bike_related_purchases', 'age', 'gender',
       'job_industry_category', 'wealth_segment', 'owns_car', 'state',
       'order_status']

# %%
Old_Cust_Ext = Old_Cust[cols]
Old_Cust_Ext.head()
# Out:
#    past_3_years_bike_related_purchases   age  gender job_industry_category  \
# 0                                   93  66.0  Female                Health
# 1                                   93  66.0  Female                Health
# 2                                   93  66.0  Female                Health
# 3                                   93  66.0  Female                Health
# 4                                   93  66.0  Female                Health
#
#   wealth_segment owns_car            state order_status
# 0  Mass Customer      Yes  New South Wales     Approved
# 1  Mass Customer      Yes  New South Wales     Approved
# 2  Mass Customer      Yes  New South Wales     Approved
# 3  Mass Customer      Yes  New South Wales     Approved
# 4  Mass Customer      Yes  New South Wales     Approved

# %%
Old_Cust_Ext['order_status'].value_counts()
# Out:
# Approved     19337
# Cancelled      176
# Name: order_status, dtype: int64

# %%
Old_Cust_Ext['order_status'] = Old_Cust_Ext['order_status'].map({'Approved': 1, 'Cancelled': 0})

# %%
Old_Cust_Ext
# Out:
#        past_3_years_bike_related_purchases   age  gender  \
# 0                                       93  66.0  Female
# 1                                       93  66.0  Female
# 2                                       93  66.0  Female
# 3                                       93  66.0  Female
# 4                                       93  66.0  Female
# ...                                    ...   ...     ...
# 19508                                   71  53.0  Female
# 19509                                   71  53.0  Female
# 19510                                   71  53.0  Female
# 19511                                   71  53.0  Female
# 19512                                   71  53.0  Female
#
#       job_industry_category     wealth_segment owns_car            state  \
# 0                    Health      Mass Customer      Yes  New South Wales
# 1                    Health      Mass Customer      Yes  New South Wales
# ...

# %% [markdown]
# # Balance the Dataset

# %%
from sklearn.utils import resample

# %%
Old_Cust_Ext_majority = Old_Cust_Ext[Old_Cust_Ext.order_status==1]
Old_Cust_Ext_minority = Old_Cust_Ext[Old_Cust_Ext.order_status==0]
Old_minority_upsampled = resample(Old_Cust_Ext_minority, replace= True, n_samples= 19337, random_state= 123)
df_upsampled = pd.concat([Old_Cust_Ext_majority, Old_minority_upsampled])

# %%
df_upsampled.order_status.value_counts()
# Out:
# 1    19337
# 0    19337
# Name: order_status, dtype: int64

# %%
df_upsampled
# Out:
#        past_3_years_bike_related_purchases   age  gender  \
# 0                                       93  66.0  Female
# 1                                       93  66.0  Female
# 2                                       93  66.0  Female
# 3                                       93  66.0  Female
# 4                                       93  66.0  Female
# ...                                    ...   ...     ...
# 16465                                   23  36.0  Female
# 11675                                   15  31.0  Female
# 1620                                    99  31.0    Male
# 980                                     25  30.0  Female
# 9944                                     1  45.0  Female
#
#       job_industry_category     wealth_segment owns_car            state  \
# 0                    Health      Mass Customer      Yes  New South Wales
# 1                    Health      Mass Customer      Yes  New South Wales
# ...

# %% [markdown]
# # Create the targets

# %%
import numpy as np
targets = df_upsampled.order_status
targets
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 16465    0
# 11675    0
# 1620     0
# 980      0
# 9944     0
# Name: order_status, Length: 38674, dtype: int64

# %%
targets.sum() / targets.shape[0]
# Out:
# 0.5

# %%
df_with_dummies = pd.get_dummies(df_upsampled, drop_first=True)
df_with_dummies
# Out:
#        past_3_years_bike_related_purchases   age  order_status  gender_Male  \
# 0                                       93  66.0             1            0
# 1                                       93  66.0             1            0
# 2                                       93  66.0             1            0
# 3                                       93  66.0             1            0
# 4                                       93  66.0             1            0
# ...                                    ...   ...           ...          ...
# 16465                                   23  36.0             0            0
# 11675                                   15  31.0             0            0
# 1620                                    99  31.0             0            1
# 980                                     25  30.0             0            0
# 9944                                     1  45.0             0            0
#
#        job_industry_category_Entertainment  \
# ...

# %% [markdown]
# # Rearrange the Columns

# %%
df_with_dummies.columns.values
# Out:
# array(['past_3_years_bike_related_purchases', 'age', 'order_status',
#        'gender_Male', 'job_industry_category_Entertainment',
#        'job_industry_category_Financial Services',
#        'job_industry_category_Health', 'job_industry_category_IT',
#        'job_industry_category_Manufacturing',
#        'job_industry_category_Property', 'job_industry_category_Retail',
#        'job_industry_category_Telecommunications',
#        'wealth_segment_High Net Worth', 'wealth_segment_Mass Customer',
#        'owns_car_Yes', 'state_Queensland', 'state_Victoria'], dtype=object)

# %%
cols = ['past_3_years_bike_related_purchases', 'age',
       'gender_Male', 'job_industry_category_Entertainment',
       'job_industry_category_Financial Services',
       'job_industry_category_Health', 'job_industry_category_IT',
       'job_industry_category_Manufacturing',
       'job_industry_category_Property', 'job_industry_category_Retail',
       'job_industry_category_Telecommunications',
       'wealth_segment_High Net Worth', 'wealth_segment_Mass Customer',
       'owns_car_Yes', 'state_Queensland', 'state_Victoria', 'order_status']

# %%
df_rearranged = df_with_dummies[cols]
df_rearranged.head()
# Out:
#    past_3_years_bike_related_purchases   age  gender_Male  \
# 0                                   93  66.0            0
# 1                                   93  66.0            0
# 2                                   93  66.0            0
# 3                                   93  66.0            0
# 4                                   93  66.0            0
#
#    job_industry_category_Entertainment  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#    job_industry_category_Financial Services  job_industry_category_Health  \
# 0                                         0                             1
# 1                                         0                             1
# 2                                         0                             1
# 3                                         0                             1
# ...

# %% [markdown]
# # Select the inputs for the regression

# %%
df_rearranged.shape
# Out:
# (38674, 17)

# %%
df_rearranged.iloc[:,:-1]
# Out:
#        past_3_years_bike_related_purchases   age  gender_Male  \
# 0                                       93  66.0            0
# 1                                       93  66.0            0
# 2                                       93  66.0            0
# 3                                       93  66.0            0
# 4                                       93  66.0            0
# ...                                    ...   ...          ...
# 16465                                   23  36.0            0
# 11675                                   15  31.0            0
# 1620                                    99  31.0            1
# 980                                     25  30.0            0
# 9944                                     1  45.0            0
#
#        job_industry_category_Entertainment  \
# 0                                        0
# 1                                        0
# 2                                        0
# ...

# %%
unscaled_inputs = df_rearranged.iloc[:,:-1]

# %% [markdown]
# # Standardize the Data

# %%
from sklearn.preprocessing import StandardScaler
Customer_scaler = StandardScaler()

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler

class CustomScaler(BaseEstimator,TransformerMixin):
    def __init__(self,columns,copy=True,with_mean=True,with_std=True):
        self.scaler = StandardScaler(copy,with_mean,with_std)
        self.columns = columns
        self.mean_ = None
        self.var_ = None
    
    def fit(self, X, y=None):
        self.scaler.fit(X[self.columns], y)
        self.mean_ = np.mean(X[self.columns])
        self.var_ = np.var(X[self.columns])
        return self
    
    def transform(self, X, y=None, copy=None):
        init_col_order = X.columns
        X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
        X_not_scaled = X.loc[:,~X.columns.isin(self.columns)]
        return pd.concat([X_not_scaled, X_scaled], axis=1)[init_col_order]

# %%
unscaled_inputs.columns.values
# Out:
# array(['past_3_years_bike_related_purchases', 'age', 'gender_Male',
#        'job_industry_category_Entertainment',
#        'job_industry_category_Financial Services',
#        'job_industry_category_Health', 'job_industry_category_IT',
#        'job_industry_category_Manufacturing',
#        'job_industry_category_Property', 'job_industry_category_Retail',
#        'job_industry_category_Telecommunications',
#        'wealth_segment_High Net Worth', 'wealth_segment_Mass Customer',
#        'owns_car_Yes', 'state_Queensland', 'state_Victoria'], dtype=object)

# %%
columns_to_omit = ['gender_Male', 'job_industry_category_Entertainment', 'job_industry_category_Financial Services', 'job_industry_category_Health','job_industry_category_IT', 'job_industry_category_Manufacturing', 'job_industry_category_Property', 'job_industry_category_Retail', 'job_industry_category_Telecommunications', 'wealth_segment_High Net Worth', 'wealth_segment_Mass Customer', 'owns_car_Yes', 'state_Queensland', 'state_Victoria']

# %%
columns_to_scale = [x for x in unscaled_inputs.columns.values if x not in columns_to_omit]

# %%
Customer_scaler = CustomScaler(columns_to_scale)

# %%
Customer_scaler.fit(unscaled_inputs)
# Out:
# CustomScaler(columns=['past_3_years_bike_related_purchases', 'age'], copy=None,
#              with_mean=None, with_std=None)

# %%
scaled_inputs = Customer_scaler.transform(unscaled_inputs)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-32-f6b4b64ae209> in <module>
# ----> 1 scaled_inputs = Customer_scaler.transform(unscaled_inputs)
#
# <ipython-input-26-86c8ad0ea893> in transform(self, X, y, copy)
#      19         X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
#      20         X_not_scaled = X.loc[:,~X.columns.isin(self.columns)]
# ---> 21         return pd.concat([X_not_scaled, X_scaled], axis=1)[init_col_order]
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ...
